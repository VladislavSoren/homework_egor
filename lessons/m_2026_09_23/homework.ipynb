# %% [markdown]
# # ДЗ:
# - Дорешать ДЗ в lessons/m_2026_09_23/homework.ipynb
# - Подготовить в текущем файле доклад про условные операторы `if, elif, else`

# %%
# я не очень хорошо пишу конспекты, так что вот
# if else переводятся с англ как: "если, иначе", например


equation = 2 + 2
if equation == 4:  # если уравнение равно 4, напечатай это
    print("ответ к задаче = 4")
else:              # иначе печатай это
    print("False")

# после if и else надо ставить двоеточия, иначе будет ошибка синтаксиса

# еще для таких задачек можно как-то сделать, чтобы пользователь вводил в терминале свое значение, например с возрастом, но уже не помню, как это делать
# спросил у ии

age = int(input("Введите свой возраст"))

if age >= 18:
    print("Ты совершеннолетний")
else:
    print("ты несовершеннолетний")
# Out:
# ответ к задаче = 4
# ты несовершеннолетний

# %%
# elif (иначе, если) нужен нам для того, если в коде будет несколько if else, Но я такое не проходил еще поэтому тут меня спас chatgpt



mark_str = input("введите вашу оценку")
try:
    mark_int = int(mark_str)
    if mark_int in [1, 2, 3, 4, 5]:
        if mark_int == 5:
            print("Отлично")
        elif mark_int == 4:
            print("Хорошо")
        elif mark_int == 3:
            print("Удовлетворительно")
        else:
            print("Не сдал")
    else:
        print("невозможная оценка")
        

except:
    print("Ввели не число")
# Out:
# Ввели не число

# %%
if 4:
    pass
