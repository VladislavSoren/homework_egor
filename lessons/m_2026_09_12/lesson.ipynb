# %%
import requests

# %%
print("Hello, World!")   


# списки
people = ['эвелина', 'влад', 'ирина', 'максим', 'ольга', 'егор']
message = 'Мою девушку зовут ' + people[0].title() + '.'
print(message)
message = 'Моего репетитора зовут ' + people[1].title() + '.'
print(message)
message = 'Мою тётю зовут ' + people[-3].title() + '.'
print(message)
message = 'Моего крестного зовут ' + people[3].title() + '.'
print(message)
message = 'Мою маму зовут ' + people[-2].title() + '.'
print(message)
message = 'Меня зовут ' + people[-1].title() + '.'
print(message)
# Out:
# Hello, World!
# Мою девушку зовут Эвелина.
# Моего репетитора зовут Влад.
# Мою тётю зовут Максим.
# Моего крестного зовут Максим.
# Мою маму зовут Ольга.
# Меня зовут Егор.

# %%
cars = ['bmw', 'audi', 'mercedes']
message = 'я бы больше всего хотел купить '.capitalize()+ cars[0].capitalize() + '.'
print(message)
cars.append('toyota')
print(cars)
cars.insert(1, 'priora')
print(cars)
del cars[0]
print(cars)
# Out:
# Я бы больше всего хотел купить Bmw.
# ['bmw', 'audi', 'mercedes', 'toyota']
# ['bmw', 'priora', 'audi', 'mercedes', 'toyota']
# ['priora', 'audi', 'mercedes', 'toyota']

# %%
" afigayfgyu ".strip()
# Out:
# 'afigayfgyu'
